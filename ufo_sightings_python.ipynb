# %% [markdown]
# # **Analysis of UFO sightings data set** to learn data analysis using python
#
# **Project goal:**
# I want to explore, clean, and analyze UFO sightings from the Kaggle dataset using Python. Learn python data analytics workflow and become comfrotable in using it for data analysis.
#
# **Overview of ufo_dataset.csv:**
# *   datetime - date and time information about the sighting
# *   city - city where the sighting occured
# *   state - state where the sighting occured
# *   country - country where the sighting occured
# *   shape - shape of the ufo
# *   duration (seconds) - duration in seconds of the sighting
# *   duration (hours/min) - duration in hours/minutes of teh sighting
# *   comments - comment describing sighting
# *   date posted - date this posting sighting made public
# *   latitude - latitude information
# *   longitude - longitude information
#
# **Process steps:**
# 1.   Getting data
# 2.   Cleaning data

# %% [markdown]
# # **Step 1. Getting data**

# %% [markdown]
# Let's import our python toolset to be able to work with our data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's read data from our CSV file.

# %%
# Read the csv file using pandas read_csv
df = pd.read_csv('./drive/MyDrive/datasets/ufo_dataset.csv')
# Out:
# <ipython-input-5-84b2417af7e0>:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./drive/MyDrive/datasets/ufo_dataset.csv')

# %% [markdown]
# Let's see first 10 lines of our dataset.

# %%
# Get first 10 records of the dataset
df.head(10)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
# 5  10/10/1961 19:00               bristol    tn      us    sphere
# 6  10/10/1965 21:00    penarth (uk/wales)   NaN      gb    circle
# 7  10/10/1965 23:45               norwalk    ct      us      disk
# 8  10/10/1966 20:00             pell city    al      us      disk
# 9  10/10/1966 21:00              live oak    fl      us      disk
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
# 5                300            5 minutes
# 6                180         about 3 mins
# 7               1200           20 minutes
# 8                180           3  minutes
# 9                120      several minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
# 5  My father is now 89 my brother 52 the girl wit...   4/27/2007      36.595
# 6  penarth uk  circle  3mins  stayed 30ft above m...   2/14/2006   51.434722
# 7  A bright orange color changing to reddish colo...  10/02/1999     41.1175
# 8  Strobe Lighted disk shape object observed clos...   3/19/2009  33.5861111
# 9  Saucer zaps energy from powerline as my pregna...  05/11/2005  30.2947222
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611
# 5  -82.188889
# 6   -3.180000
# 7  -73.408333
# 8  -86.286111
# 9  -82.984167

# %% [markdown]
# Let's see general information about our dataset.

# %%
# General information about the dataset using df.info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %% [markdown]
# **What can we see?**
# In total there is 80332 entries in this dataset. This dataset contains records of UFO sightings around the world. Some of the columns have missing values like **country, state, shape, comments and longitude**

# %% [markdown]
# # **Step 2. Processing Data**

# %% [markdown]
# In this step we will look at our data whether we are renaming columns, removing duplicates, changing types or dealing with missing values our mission during this step is to ensure the data is in it's best shape for us to work with.

# %% [markdown]
# First we will create a copy of our data frame and store it in a variable df_processing.

# %%
# Create a copy of the imported dataframe
df_processing = df.copy()

# %% [markdown]
# Let's look at our column names.

# %%
# Retrieve column names from the dataset
df_processing.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %% [markdown]
# We would wan't to **remove spaces** in our column names and **symbols** as this will make our life easier when working with column names. We will also remove a trailing space in our longitude column

# %%
# Lets use rename and dictionary to rename multiple columns at the same time
df_processing.rename(columns={
    'duration (seconds)': 'duration_seconds',
    'duration (hours/min)': 'duration_hours_min',
    'date posted': 'date_posted',
    'longitude ': 'longitude'
}, inplace=True)

# Let's check the resulting column names
df_processing.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration_seconds',
#        'duration_hours_min', 'comments', 'date_posted', 'latitude',
#        'longitude'],
#       dtype='object')

# %% [markdown]
# Lets also check our dataset for any duplicates.

# %%
# Display number of duplicated records
df_processing.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Lets check our data frame for missing values.

# %%
# Display sum of missing values
df_processing.isnull().sum()
# Out:
# datetime                 0
# city                     0
# state                 5797
# country               9670
# shape                 1932
# duration_seconds         0
# duration_hours_min       0
# comments                15
# date_posted              0
# latitude                 0
# longitude                0
# dtype: int64

# %% [markdown]
# We can see that our **state column** is **missing 5797 values**, **country** is **missing 9670 values**, **shape** is **missing 1932 value**s and **comments** and **longitude** both **missing 1 value**.

# %% [markdown]
# Lets start by looking at our records that are missing country and see if we are able to fix our data by filling the missing values.

# %%
# Select records that are missing country
df_processing[df_processing['country'].isnull()]
# Out:
#                datetime                    city state country      shape  \
# 1      10/10/1949 21:00            lackland afb    tx     NaN      light
# 18     10/10/1973 23:00             bermuda nas   NaN     NaN      light
# 29     10/10/1979 22:00    saddle lake (canada)    ab     NaN   triangle
# 35     10/10/1982 07:00  gisborne (new zealand)   NaN     NaN       disk
# 40     10/10/1986 20:00          holmes/pawling    ny     NaN    chevron
# ...                 ...                     ...   ...     ...        ...
# 80238  09/09/2009 14:15    broomfield?lafayette    co     NaN  rectangle
# 80244  09/09/2009 20:17                   lyman    me     NaN      light
# 80319  09/09/2013 20:15                 clifton    nj     NaN      other
# 80322  09/09/2013 21:00    aleksandrow (poland)   NaN     NaN      light
# 80324  09/09/2013 21:00   hamstead (hollyridge)    nc     NaN      light
#
#       duration_seconds duration_hours_min  \
# 1                 7200            1-2 hrs
# 18                  20            20 sec.
# 29                 270   4.5 or more min.
# 35                 120               2min
# 40                 180          3 minutes
# ...                ...                ...
# 80238            120.0              2 min
# 80244            600.0            10 mins
# 80319           3600.0              ~1hr+
# 80322             15.0         15 seconds
# 80324            120.0          2 minutes
#
#                                                 comments date_posted  \
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 18     saw fast moving blip on the radar scope thin w...  01/11/2002
# 29     Lights far above&#44  that glance; then flee f...   1/19/2005
# 35           gisborne nz 1982 wainui beach to sponge bay  01/11/2002
# 40     Football Field Sized Chevron with bright white...  10/08/2007
# ...                                                  ...         ...
# 80238  Large&#44 rectangular object seen flying in br...  12/12/2009
# 80244  Two lights ran across the sky&#44 as bright as...  12/12/2009
# 80319              Luminous line seen in New Jersey sky.   9/30/2013
# 80322  Two points of light following one another in a...   9/30/2013
# 80324  8 to ten lights bright orange in color large t...   9/30/2013
#
#          latitude   longitude
# 1        29.38421  -98.581082
# 18      32.364167  -64.678611
# 29      53.970571 -111.689885
# 35     -38.662334  178.017649
# 40      41.523427  -73.646795
# ...           ...         ...
# 80238   39.993596 -105.089706
# 80244   43.505096  -70.637968
# 80319   40.858433  -74.163755
# 80322   50.465843   22.891814
# 80324   34.367594  -77.710548
#
# [9670 rows x 11 columns]

# %%
# Select records that are missing country
df_processing[df_processing['state'].isnull()]
# Out:
#                datetime                           city state country  \
# 2      10/10/1955 17:00           chester (uk/england)   NaN      gb
# 6      10/10/1965 21:00             penarth (uk/wales)   NaN      gb
# 18     10/10/1973 23:00                    bermuda nas   NaN     NaN
# 20     10/10/1974 21:30             cardiff (uk/wales)   NaN      gb
# 24     10/10/1976 22:00  stoke mandeville (uk/england)   NaN      gb
# ...                 ...                            ...   ...     ...
# 80217  09/09/2007 19:01          melbourne (australia)   NaN      au
# 80234  09/09/2009 03:14         aberdeen (uk/scotland)   NaN      gb
# 80254  09/09/2009 21:15   nottinghamshire (uk/england)   NaN      gb
# 80255  09/09/2009 21:38        kaiserlautern (germany)   NaN      de
# 80322  09/09/2013 21:00           aleksandrow (poland)   NaN     NaN
#
#           shape duration_seconds duration_hours_min  \
# 2        circle               20         20 seconds
# 6        circle              180       about 3 mins
# 18        light               20            20 sec.
# 20         disk             1200         20 minutes
# 24        cigar                3          3 seconds
# ...         ...              ...                ...
# 80217    circle            600.0             10 min
# 80234     light              6.0          6 seconds
# 80254  fireball            600.0            10 mins
# 80255     light             40.0   about 40 seconds
# 80322     light             15.0         15 seconds
#
#                                                 comments date_posted  \
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 6      penarth uk  circle  3mins  stayed 30ft above m...   2/14/2006
# 18     saw fast moving blip on the radar scope thin w...  01/11/2002
# 20     back in 1974 I was 19 at the time and  lived i...  02/01/2007
# 24                 White object over Buckinghamshire UK.  12/12/2009
# ...                                                  ...         ...
# 80217                                            Hostile  10/08/2007
# 80234  Bright light seen over Aberdeen&#44 Scotland&#...  12/12/2009
# 80254  resembled orange flame imagine a transparent h...  12/12/2009
# 80255  2 white lights over Kaiserslautern&#44 ramstei...  12/12/2009
# 80322  Two points of light following one another in a...   9/30/2013
#
#         latitude   longitude
# 2           53.2   -2.916667
# 6      51.434722   -3.180000
# 18     32.364167  -64.678611
# 20          51.5   -3.200000
# 24     51.783333   -0.783333
# ...          ...         ...
# 80217 -37.813938  144.963425
# 80234  57.166667   -2.666667
# 80254  53.166667   -1.000000
# 80255      49.45    7.750000
# 80322  50.465843   22.891814
#
# [5797 rows x 11 columns]

# %% [markdown]
# As we can see there is alot of missing data. Some records contain the country in the city column some don't. We could possibly extract this data an fill in the missing values. However we do have longitude and latitude data an perhaps should be able to use some kind of geolocation API to replace the missing data.

# %% [markdown]
# After some digging we could potentially use the longitude and latitude data to fix our missing country, state values a by using something like **geopy** with it's **Nominatim** module.

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
import time
from tqdm import tqdm
